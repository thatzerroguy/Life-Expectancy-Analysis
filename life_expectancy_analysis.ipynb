# %% [markdown]
# Importing the following libraries for the analysis.
# 1. Numpy for scientific computing
# 2. Pandas for analysis
# 3. Seaborn for visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# We now load the dataset

# %%
life_data = pd.read_csv('lifeX - lifeX.csv')

# %%
life_data.shape
# Out:
# (732, 14)

# %%
life_data.head()
# Out:
#        country  year  life_expectancy_birth_both  life_expectancy_birth_male  \
# 0  Afghanistan  2019                        63.2                        63.3
# 1  Afghanistan  2015                        61.7                        61.0
# 2  Afghanistan  2010                        59.9                        59.6
# 3  Afghanistan  2000                        55.0                        54.6
# 4      Albania  2019                        78.0                        76.3
#
#    life_expectancy_birth_female  life_expectancy_age_60_both  \
# 0                          63.2                         15.2
# 1                          62.3                         15.6
# 2                          60.3                         15.1
# 3                          55.4                         13.9
# 4                          79.9                         21.0
#
#    life_expectancy_age_60_male  life_expectancy_age_60_female  \
# 0                         15.4                           15.1
# ...

# %%
life_data.tail()
# Out:
#       country  year  life_expectancy_birth_both  life_expectancy_birth_male  \
# 727    Zambia  2000                        44.5                        43.7
# 728  Zimbabwe  2019                        60.7                        57.5
# 729  Zimbabwe  2015                        58.5                        55.7
# 730  Zimbabwe  2010                        51.5                        49.6
# 731  Zimbabwe  2000                        46.6                        45.1
#
#      life_expectancy_birth_female  life_expectancy_age_60_both  \
# 727                          45.2                         13.2
# 728                          63.6                         15.6
# 729                          61.0                         15.1
# 730                          53.2                         14.1
# 731                          48.1                         14.4
#
#      life_expectancy_age_60_male  life_expectancy_age_60_female  \
# ...

# %%
life_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        731 non-null    object
#  1   year                           732 non-null    int64
#  2   life_expectancy_birth_both     732 non-null    float64
#  3   life_expectancy_birth_male     732 non-null    float64
#  4   life_expectancy_birth_female   732 non-null    float64
#  5   life_expectancy_age_60_both    732 non-null    float64
#  6   life_expectancy_age_60_male    732 non-null    float64
#  7   life_expectancy_age_60_female  732 non-null    float64
#  8   hale_birth_both                726 non-null    float64
#  9   hale_birth_male                732 non-null    float64
#  10  hale_birth_female              732 non-null    float64
#  11  hale_age_60_both               732 non-null    float64
# ...

# %%
life_data.describe()
# Out:
#               year  life_expectancy_birth_both  life_expectancy_birth_male  \
# count   732.000000                  732.000000                  732.000000
# mean   2008.528689                   70.197951                   67.768989
# std      67.276452                    8.672693                    8.565990
# min     201.000000                   31.300000                   28.000000
# 25%    2000.000000                   64.400000                   62.100000
# 50%    2012.500000                   72.100000                   69.300000
# 75%    2016.000000                   76.400000                   74.100000
# max    2019.000000                   84.300000                   81.800000
#
#        life_expectancy_birth_female  life_expectancy_age_60_both  \
# count                    732.000000                   732.000000
# mean                      72.692760                    19.143169
# std                        8.862384                     3.052167
# ...

# %%
life_data.isna().sum()
# Out:
# country                          1
# year                             0
# life_expectancy_birth_both       0
# life_expectancy_birth_male       0
# life_expectancy_birth_female     0
# life_expectancy_age_60_both      0
# life_expectancy_age_60_male      0
# life_expectancy_age_60_female    0
# hale_birth_both                  6
# hale_birth_male                  0
# hale_birth_female                0
# hale_age_60_both                 0
# hale_age_60_male                 0
# hale_age_60_female               0
# dtype: int64

# %%
life_data[life_data['country'].isna()]
# Out:
#     country  year  life_expectancy_birth_both  life_expectancy_birth_male  \
# 363     NaN  2000                        58.4                        56.3
#
#      life_expectancy_birth_female  life_expectancy_age_60_both  \
# 363                          60.6                         15.3
#
#      life_expectancy_age_60_male  life_expectancy_age_60_female  \
# 363                         14.0                           16.5
#
#      hale_birth_both  hale_birth_male  hale_birth_female  hale_age_60_both  \
# 363             51.8             50.5               53.1              11.6
#
#      hale_age_60_male  hale_age_60_female
# 363              10.8                12.3

# %%
life_data['country'].fillna("Lao People's Democratic Republic", inplace=True)

# %%
life_data.isna().sum()
# Out:
# country                          0
# year                             0
# life_expectancy_birth_both       0
# life_expectancy_birth_male       0
# life_expectancy_birth_female     0
# life_expectancy_age_60_both      0
# life_expectancy_age_60_male      0
# life_expectancy_age_60_female    0
# hale_birth_both                  6
# hale_birth_male                  0
# hale_birth_female                0
# hale_age_60_both                 0
# hale_age_60_male                 0
# hale_age_60_female               0
# dtype: int64

# %%
life_data[life_data['hale_birth_both'].isna()]
# Out:
#         country  year  life_expectancy_birth_both  life_expectancy_birth_male  \
# 501    Paraguay  2015                        75.6                        72.8
# 502    Paraguay  2010                        75.0                        72.5
# 504        Peru  2019                        79.9                        78.5
# 556       Samoa  2019                        70.5                        69.2
# 559       Samoa  2000                        68.5                        66.5
# 641  Tajikistan  2015                        68.7                        66.7
#
#      life_expectancy_birth_female  life_expectancy_age_60_both  \
# 501                          78.6                         21.8
# 502                          77.7                         21.6
# 504                          81.3                         24.4
# 556                          71.8                         17.9
# 559                          70.8                         17.1
# ...

# %%
average_hale_birth_male_female = (life_data['hale_birth_male'] + life_data['hale_birth_female']) / 2

# %%
life_data['hale_birth_both'].fillna(average_hale_birth_male_female, inplace=True)

# %%
life_data.isna().sum()
# Out:
# country                          0
# year                             0
# life_expectancy_birth_both       0
# life_expectancy_birth_male       0
# life_expectancy_birth_female     0
# life_expectancy_age_60_both      0
# life_expectancy_age_60_male      0
# life_expectancy_age_60_female    0
# hale_birth_both                  0
# hale_birth_male                  0
# hale_birth_female                0
# hale_age_60_both                 0
# hale_age_60_male                 0
# hale_age_60_female               0
# dtype: int64

# %%
sns.jointplot(x = 'year', y = 'life_expectancy_birth_both', data=life_data)
